# %%
import pandas as pd
var = pd.read_csv("C:\\Users\\Paras\\Desktop\\jupyter projects\\pandas\\ttt.csv",encoding='latin-1')
var
# Out:
#       1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2     4                                               R380      Clay Rozendal
# 3     5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# ..  ...                                                ...                ...
# 94   96              Linden® 12" Wall Clock With Oak Frame      Doug Bickford
# 95   97                                         Newell 326      Doug Bickford
# 96   98                       Prismacolor Color Pencil Set       Jamie Kunitz
# 97   99                         Xerox Blank Computer Paper    Anthony Johnson
# 98  100                                    600 Series Flip       Ralph Knight
#
# ...

# %% [markdown]
# # missing data drop:

# %%
var.dropna()
# Out:
#       1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2     4                                               R380      Clay Rozendal
# 3     5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# ..  ...                                                ...                ...
# 94   96              Linden® 12" Wall Clock With Oak Frame      Doug Bickford
# 95   97                                         Newell 326      Doug Bickford
# 96   98                       Prismacolor Color Pencil Set       Jamie Kunitz
# 97   99                         Xerox Blank Computer Paper    Anthony Johnson
# 98  100                                    600 Series Flip       Ralph Knight
#
# ...

# %%
import pandas as pd
var = pd.read_csv("C:\\Users\\Paras\\Desktop\\jupyter projects\\pandas\\ttt.csv",encoding='latin-1')
var
# Out:
#       1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2     4                                               R380      Clay Rozendal
# 3     5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# ..  ...                                                ...                ...
# 94   96              Linden® 12" Wall Clock With Oak Frame      Doug Bickford
# 95   97                                         Newell 326      Doug Bickford
# 96   98                       Prismacolor Color Pencil Set       Jamie Kunitz
# 97   99                         Xerox Blank Computer Paper    Anthony Johnson
# 98  100                                    600 Series Flip       Ralph Knight
#
# ...

# %% [markdown]
# # All none value remove :

# %%
var.dropna(how="any")
# Out:
#       1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2     4                                               R380      Clay Rozendal
# 3     5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# ..  ...                                                ...                ...
# 94   96              Linden® 12" Wall Clock With Oak Frame      Doug Bickford
# 95   97                                         Newell 326      Doug Bickford
# 96   98                       Prismacolor Color Pencil Set       Jamie Kunitz
# 97   99                         Xerox Blank Computer Paper    Anthony Johnson
# 98  100                                    600 Series Flip       Ralph Knight
#
# ...

# %% [markdown]
# # Show all none value:

# %%
var.dropna(how="all")
# Out:
#       1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2     4                                               R380      Clay Rozendal
# 3     5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# ..  ...                                                ...                ...
# 94   96              Linden® 12" Wall Clock With Oak Frame      Doug Bickford
# 95   97                                         Newell 326      Doug Bickford
# 96   98                       Prismacolor Color Pencil Set       Jamie Kunitz
# 97   99                         Xerox Blank Computer Paper    Anthony Johnson
# 98  100                                    600 Series Flip       Ralph Knight
#
# ...

# %% [markdown]
# # Fillna:

# %%
var.fillna("python")
# Out:
#       1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2     4                                               R380      Clay Rozendal
# 3     5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# ..  ...                                                ...                ...
# 94   96              Linden® 12" Wall Clock With Oak Frame      Doug Bickford
# 95   97                                         Newell 326      Doug Bickford
# 96   98                       Prismacolor Color Pencil Set       Jamie Kunitz
# 97   99                         Xerox Blank Computer Paper    Anthony Johnson
# 98  100                                    600 Series Flip       Ralph Knight
#
# ...

# %% [markdown]
# # Handling and , missing values :

# %% [markdown]
# # replace :

# %%
var.replace(to_replace=293,value=33)
# Out:
#       1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2     4                                               R380      Clay Rozendal
# 3     5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# ..  ...                                                ...                ...
# 94   96              Linden® 12" Wall Clock With Oak Frame      Doug Bickford
# 95   97                                         Newell 326      Doug Bickford
# 96   98                       Prismacolor Color Pencil Set       Jamie Kunitz
# 97   99                         Xerox Blank Computer Paper    Anthony Johnson
# 98  100                                    600 Series Flip       Ralph Knight
#
# ...

# %% [markdown]
# # Missing data:

# %% [markdown]
# # interpolate: only work on number|

# %%
import pandas as pd
var = pd.read_csv("C:\\Users\\Paras\\Desktop\\jupyter projects\\pandas\\ttt.csv",encoding='latin-1')
var
# Out:
#       1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1     3                                                NaN       Barry French
# 2     4                                               R380      Clay Rozendal
# 3     5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# ..  ...                                                ...                ...
# 94   96              Linden® 12" Wall Clock With Oak Frame      Doug Bickford
# 95   97                                         Newell 326      Doug Bickford
# 96   98                       Prismacolor Color Pencil Set       Jamie Kunitz
# 97   99                         Xerox Blank Computer Paper    Anthony Johnson
# 98  100                                    600 Series Flip       Ralph Knight
#
# ...

# %%
var.interpolate()
# Out:
# C:\Users\Paras\AppData\Local\Temp\ipykernel_24288\1566664964.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   var.interpolate()
#       1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1     3                                                NaN       Barry French
# 2     4                                               R380      Clay Rozendal
# 3     5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# ..  ...                                                ...                ...
# 94   96              Linden® 12" Wall Clock With Oak Frame      Doug Bickford
# 95   97                                         Newell 326      Doug Bickford
# ...

# %% [markdown]
# # method: {'linear', 'time', 'index', 'values', 'nearest', 'zero', 'slinear', 'quadratic', 'cubic', 'barycentric', 'krogh', 'polynomial', 'spline', 'piecewise_polynomial', 'from_derivatives', 'pchip', 'akima'}

# %%
var.interpolate(method="linear")
# Out:
# C:\Users\Paras\AppData\Local\Temp\ipykernel_24288\906631510.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   var.interpolate(method="linear")
#       1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1     3                                                NaN       Barry French
# 2     4                                               R380      Clay Rozendal
# 3     5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# ..  ...                                                ...                ...
# 94   96              Linden® 12" Wall Clock With Oak Frame      Doug Bickford
# 95   97                                         Newell 326      Doug Bickford
# ...
